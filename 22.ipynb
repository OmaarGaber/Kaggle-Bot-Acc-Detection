# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('D:\data sets\kaggle_bot_accounts.csv')

# %% [markdown]
# ### Explore Data

# %%
df
# Out:
#          Unnamed: 0                      NAME  GENDER  \
# 0                 0         Johnny KerrThomas    Male
# 1                 1         Dwayne LarsenLara    Male
# 2                 2                       NaN    Male
# 3                 3   Russell SimmonsPhillips    Male
# 4                 4      Jamie WilsonMartinez  Female
# ...             ...                       ...     ...
# 1321183     1321183       Kristen MooreJoseph  Female
# 1321184     1321184  Kimberly ThomasGutierrez  Female
# 1321185     1321185         Hector TerryLogan    Male
# 1321186     1321186   William CollinsMartinez     NaN
# 1321187     1321187     Susan WilliamsJimenez  Female
#
#                             EMAIL_ID IS_GLOGIN  FOLLOWER_COUNT  \
# 0            jacksonalan@example.com     False            53.0
# 1               calvin80@example.com      True            16.0
# 2                 qbrown@example.net      True            44.0
# 3         kimberlywagner@example.com      True            23.0
# 4            shaunbrooks@example.com     False            46.0
# ...                              ...       ...             ...
# 1321183  penningtondebra@example.net     False             1.0
# 1321184      kerrycastro@example.com      True            20.0
# 1321185       jonesmisty@example.net      True            20.0
# 1321186           erin58@example.net     False             0.0
# 1321187                          NaN     False             0.0
#
#          FOLLOWING_COUNT  DATASET_COUNT  CODE_COUNT  DISCUSSION_COUNT  \
# 0                   87.0            5.0         3.0             124.0
# 1                   67.0            5.0         NaN              26.0
# 2                   81.0            4.0        17.0             125.0
# 3                  114.0            5.0        24.0              67.0
# 4                  112.0            2.0        12.0              63.0
# ...                  ...            ...         ...               ...
# 1321183              3.0            0.0         1.0               9.0
# 1321184             60.0            6.0        14.0              44.0
# 1321185             64.0            3.0        24.0              67.0
# 1321186              1.0            0.0         0.0               3.0
# 1321187              3.0            0.0         NaN               0.0
#
#          AVG_NB_READ_TIME_MIN REGISTRATION_IPV4  \
# 0                         NaN      81.88.75.170
# 1                       24.97               NaN
# 2                        7.75   159.202.103.178
# 3                       13.40     196.11.132.51
# 4                       24.83    159.196.199.20
# ...                       ...               ...
# 1321183                  0.26    46.209.124.151
# 1321184                 23.39   220.247.154.162
# 1321185                  9.49    150.144.209.44
# 1321186                  1.70    146.121.179.46
# 1321187                  0.53     118.38.253.89
#
#                         REGISTRATION_LOCATION  TOTAL_VOTES_GAVE_NB  \
# 0                                   Argentina                 16.0
# 1                                 New Zealand                 14.0
# 2                                  Costa Rica                 16.0
# 3                                       Italy                 21.0
# 4                                     Belgium                 10.0
# ...                                       ...                  ...
# 1321183  United States Minor Outlying Islands                 25.0
# 1321184                               Algeria                 22.0
# 1321185                               Croatia                 24.0
# 1321186                                   NaN                 14.0
# 1321187                          Cook Islands                 24.0
#
#          TOTAL_VOTES_GAVE_DS  TOTAL_VOTES_GAVE_DC  ISBOT
# 0                       10.0                  3.0    NaN
# 1                        5.0                  2.0    NaN
# 2                        4.0                  0.0  False
# 3                       10.0                  1.0  False
# 4                        6.0                  2.0  False
# ...                      ...                  ...    ...
# 1321183                 10.0                  NaN   True
# 1321184                 10.0                  3.0  False
# 1321185                  7.0                  0.0  False
# 1321186                  8.0                  NaN   True
# 1321187                  9.0                  0.0   True
#
# [1321188 rows x 17 columns]

# %%
df.head(10)
# Out:
#    Unnamed: 0                      NAME  GENDER                    EMAIL_ID  \
# 0           0         Johnny KerrThomas    Male     jacksonalan@example.com
# 1           1         Dwayne LarsenLara    Male        calvin80@example.com
# 2           2                       NaN    Male          qbrown@example.net
# 3           3   Russell SimmonsPhillips    Male  kimberlywagner@example.com
# 4           4      Jamie WilsonMartinez  Female     shaunbrooks@example.com
# 5           5           Elijah ParkNeal    Male        mpearson@example.org
# 6           6  Logan ZimmermanGallagher    Male   sparkschristy@example.org
# 7           7          Erin HerreraKing  Female                         NaN
# 8           8      Matthew RobertsGreer    Male    harrisregina@example.org
# 9           9       Michael StoutGraves    Male          klopez@example.net
#
#   IS_GLOGIN  FOLLOWER_COUNT  FOLLOWING_COUNT  DATASET_COUNT  CODE_COUNT  \
# 0     False            53.0             87.0            5.0         3.0
# 1      True            16.0             67.0            5.0         NaN
# 2      True            44.0             81.0            4.0        17.0
# 3      True            23.0            114.0            5.0        24.0
# 4     False            46.0            112.0            2.0        12.0
# 5     False             2.0              2.0            0.0         0.0
# 6       NaN            46.0             36.0            0.0        16.0
# 7     False             2.0              1.0            0.0         0.0
# 8      True            50.0             25.0            1.0         7.0
# 9      True            65.0             99.0            7.0        19.0
#
#    DISCUSSION_COUNT  AVG_NB_READ_TIME_MIN REGISTRATION_IPV4  \
# 0             124.0                   NaN      81.88.75.170
# 1              26.0                 24.97               NaN
# 2             125.0                  7.75   159.202.103.178
# 3              67.0                 13.40     196.11.132.51
# 4              63.0                 24.83    159.196.199.20
# 5               0.0                  0.62     72.175.201.72
# 6              77.0                 22.32    133.206.76.136
# 7               6.0                  1.85     39.214.115.81
# 8             122.0                   NaN    192.177.30.226
# 9              93.0                  8.79     68.230.133.41
#
#                           REGISTRATION_LOCATION  TOTAL_VOTES_GAVE_NB  \
# 0                                     Argentina                 16.0
# 1                                   New Zealand                 14.0
# 2                                    Costa Rica                 16.0
# 3                                         Italy                 21.0
# 4                                       Belgium                 10.0
# 5                              French Polynesia                 18.0
# 6  South Georgia and the South Sandwich Islands                  NaN
# 7  Antarctica (the territory South of 60 deg S)                 21.0
# 8                                           NaN                  NaN
# 9                                   Saint Lucia                 24.0
#
#    TOTAL_VOTES_GAVE_DS  TOTAL_VOTES_GAVE_DC  ISBOT
# 0                 10.0                  3.0    NaN
# 1                  5.0                  2.0    NaN
# 2                  4.0                  0.0  False
# 3                 10.0                  1.0  False
# 4                  6.0                  2.0  False
# 5                  9.0                  2.0   True
# 6                  9.0                  1.0  False
# 7                  3.0                  1.0   True
# 8                  7.0                  3.0  False
# 9                  7.0                  2.0  False

# %%
df.tail()
# Out:
#          Unnamed: 0                      NAME  GENDER  \
# 1321183     1321183       Kristen MooreJoseph  Female
# 1321184     1321184  Kimberly ThomasGutierrez  Female
# 1321185     1321185         Hector TerryLogan    Male
# 1321186     1321186   William CollinsMartinez     NaN
# 1321187     1321187     Susan WilliamsJimenez  Female
#
#                             EMAIL_ID IS_GLOGIN  FOLLOWER_COUNT  \
# 1321183  penningtondebra@example.net     False             1.0
# 1321184      kerrycastro@example.com      True            20.0
# 1321185       jonesmisty@example.net      True            20.0
# 1321186           erin58@example.net     False             0.0
# 1321187                          NaN     False             0.0
#
#          FOLLOWING_COUNT  DATASET_COUNT  CODE_COUNT  DISCUSSION_COUNT  \
# 1321183              3.0            0.0         1.0               9.0
# 1321184             60.0            6.0        14.0              44.0
# 1321185             64.0            3.0        24.0              67.0
# 1321186              1.0            0.0         0.0               3.0
# 1321187              3.0            0.0         NaN               0.0
#
#          AVG_NB_READ_TIME_MIN REGISTRATION_IPV4  \
# 1321183                  0.26    46.209.124.151
# 1321184                 23.39   220.247.154.162
# 1321185                  9.49    150.144.209.44
# 1321186                  1.70    146.121.179.46
# 1321187                  0.53     118.38.253.89
#
#                         REGISTRATION_LOCATION  TOTAL_VOTES_GAVE_NB  \
# 1321183  United States Minor Outlying Islands                 25.0
# 1321184                               Algeria                 22.0
# 1321185                               Croatia                 24.0
# 1321186                                   NaN                 14.0
# 1321187                          Cook Islands                 24.0
#
#          TOTAL_VOTES_GAVE_DS  TOTAL_VOTES_GAVE_DC  ISBOT
# 1321183                 10.0                  NaN   True
# 1321184                 10.0                  3.0  False
# 1321185                  7.0                  0.0  False
# 1321186                  8.0                  NaN   True
# 1321187                  9.0                  0.0   True

# %%
df.describe()
# Out:
#          Unnamed: 0  FOLLOWER_COUNT  FOLLOWING_COUNT  DATASET_COUNT  \
# count  1.321188e+06    1.243476e+06     1.242743e+06   1.242621e+06
# mean   6.605935e+05    2.698273e+01     4.505091e+01   2.562564e+00
# std    3.813943e+05    2.300504e+01     3.947716e+01   2.499882e+00
# min    0.000000e+00    0.000000e+00     0.000000e+00   0.000000e+00
# 25%    3.302968e+05    2.000000e+00     3.000000e+00   0.000000e+00
# 50%    6.605935e+05    2.400000e+01     3.900000e+01   2.000000e+00
# 75%    9.908902e+05    4.700000e+01     8.000000e+01   5.000000e+00
# max    1.321187e+06    7.000000e+01     1.200000e+02   7.000000e+00
#
#          CODE_COUNT  DISCUSSION_COUNT  AVG_NB_READ_TIME_MIN  \
# count  1.243262e+06      1.243466e+06          1.242872e+06
# mean   1.038450e+01      6.584244e+01          1.274225e+01
# std    8.248055e+00      4.754315e+01          9.564920e+00
# min    0.000000e+00      0.000000e+00          0.000000e+00
# 25%    1.000000e+00      1.300000e+01          1.870000e+00
# 50%    1.000000e+01      6.500000e+01          1.229000e+01
# 75%    1.800000e+01      1.080000e+02          2.119000e+01
# max    2.500000e+01      1.500000e+02          2.999000e+01
#
#        TOTAL_VOTES_GAVE_NB  TOTAL_VOTES_GAVE_DS  TOTAL_VOTES_GAVE_DC
# count         1.243483e+06         1.243254e+06         1.243158e+06
# mean          1.750656e+01         6.501007e+00         1.500373e+00
# std           4.611783e+00         2.290951e+00         1.118067e+00
# min           1.000000e+01         3.000000e+00         0.000000e+00
# 25%           1.400000e+01         5.000000e+00         1.000000e+00
# 50%           1.800000e+01         7.000000e+00         2.000000e+00
# 75%           2.200000e+01         9.000000e+00         3.000000e+00
# max           2.500000e+01         1.000000e+01         3.000000e+00

# %%
print("num of rows is -> ",df.shape[0])
print("num of columns is -> ",df.shape[1])
# Out:
# num of rows is ->  1321188
# num of columns is ->  17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1321188 entries, 0 to 1321187
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1321188 non-null  int64
#  1   NAME                   1243024 non-null  object
#  2   GENDER                 1243309 non-null  object
#  3   EMAIL_ID               1243374 non-null  object
#  4   IS_GLOGIN              1243272 non-null  object
#  5   FOLLOWER_COUNT         1243476 non-null  float64
#  6   FOLLOWING_COUNT        1242743 non-null  float64
#  7   DATASET_COUNT          1242621 non-null  float64
#  8   CODE_COUNT             1243262 non-null  float64
#  9   DISCUSSION_COUNT       1243466 non-null  float64
#  10  AVG_NB_READ_TIME_MIN   1242872 non-null  float64
#  11  REGISTRATION_IPV4      1242859 non-null  object
#  12  REGISTRATION_LOCATION  1242898 non-null  object
#  13  TOTAL_VOTES_GAVE_NB    1243483 non-null  float64
#  14  TOTAL_VOTES_GAVE_DS    1243254 non-null  float64
#  15  TOTAL_VOTES_GAVE_DC    1243158 non-null  float64
#  16  ISBOT                  1242688 non-null  object
# dtypes: float64(9), int64(1), object(7)
# memory usage: 171.4+ MB

# %%
df.count()
# Out:
# Unnamed: 0               1321188
# NAME                     1243024
# GENDER                   1243309
# EMAIL_ID                 1243374
# IS_GLOGIN                1243272
# FOLLOWER_COUNT           1243476
# FOLLOWING_COUNT          1242743
# DATASET_COUNT            1242621
# CODE_COUNT               1243262
# DISCUSSION_COUNT         1243466
# AVG_NB_READ_TIME_MIN     1242872
# REGISTRATION_IPV4        1242859
# REGISTRATION_LOCATION    1242898
# TOTAL_VOTES_GAVE_NB      1243483
# TOTAL_VOTES_GAVE_DS      1243254
# TOTAL_VOTES_GAVE_DC      1243158
# ISBOT                    1242688
# dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# float64    9
# object     7
# int64      1
# dtype: int64

# %%
df.shape
# Out:
# (1321188, 17)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'NAME', 'GENDER', 'EMAIL_ID', 'IS_GLOGIN',
#        'FOLLOWER_COUNT', 'FOLLOWING_COUNT', 'DATASET_COUNT', 'CODE_COUNT',
#        'DISCUSSION_COUNT', 'AVG_NB_READ_TIME_MIN', 'REGISTRATION_IPV4',
#        'REGISTRATION_LOCATION', 'TOTAL_VOTES_GAVE_NB', 'TOTAL_VOTES_GAVE_DS',
#        'TOTAL_VOTES_GAVE_DC', 'ISBOT'],
#       dtype='object')

# %%
df['GENDER'].value_counts()
# Out:
# Male      932220
# Female    311089
# Name: GENDER, dtype: int64

# %%
con = df['REGISTRATION_LOCATION'].value_counts()
con
# Out:
# Korea                      10128
# Congo                      10045
# Costa Rica                  5304
# Canada                      5261
# Cocos (Keeling) Islands     5241
#                            ...
# Nicaragua                   4912
# Azerbaijan                  4910
# New Caledonia               4902
# Chile                       4877
# Monaco                      4874
# Name: REGISTRATION_LOCATION, Length: 243, dtype: int64

# %%
con.max()
# Out:
# 10128

# %% [markdown]
# ### Data Cleaning

# %%
df.rename(columns={'Unnamed: 0':'Acc_Num '},inplace = True)

# %%
df.isnull().sum()
# Out:
# Acc_Num                      0
# NAME                     78164
# GENDER                   77879
# EMAIL_ID                 77814
# IS_GLOGIN                77916
# FOLLOWER_COUNT           77712
# FOLLOWING_COUNT          78445
# DATASET_COUNT            78567
# CODE_COUNT               77926
# DISCUSSION_COUNT         77722
# AVG_NB_READ_TIME_MIN     78316
# REGISTRATION_IPV4        78329
# REGISTRATION_LOCATION    78290
# TOTAL_VOTES_GAVE_NB      77705
# TOTAL_VOTES_GAVE_DS      77934
# TOTAL_VOTES_GAVE_DC      78030
# ISBOT                    78500
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 1249249

# %%
df.replace([np.inf,-np.inf],np.nan , inplace = True )
# df.replace(np.nan,'Emp_Cell',inplace=True)
# df.replace('Emp_Cell',0,inplace=True)
# df.replace(0,'Emp_Cell',inplace=True)
# df.replace(np.nan,'Emp_Cell',inplace=True)

df.replace('Emp_Cell',0,inplace=True)


df
# Out:
#          Acc_Num                       NAME  GENDER  \
# 0               0         Johnny KerrThomas    Male
# 1               1         Dwayne LarsenLara    Male
# 2               2                         0    Male
# 3               3   Russell SimmonsPhillips    Male
# 4               4      Jamie WilsonMartinez  Female
# ...           ...                       ...     ...
# 1321183   1321183       Kristen MooreJoseph  Female
# 1321184   1321184  Kimberly ThomasGutierrez  Female
# 1321185   1321185         Hector TerryLogan    Male
# 1321186   1321186   William CollinsMartinez       0
# 1321187   1321187     Susan WilliamsJimenez  Female
#
#                             EMAIL_ID IS_GLOGIN  FOLLOWER_COUNT  \
# 0            jacksonalan@example.com         0            53.0
# 1               calvin80@example.com      True            16.0
# 2                 qbrown@example.net      True            44.0
# 3         kimberlywagner@example.com      True            23.0
# 4            shaunbrooks@example.com         0            46.0
# ...                              ...       ...             ...
# 1321183  penningtondebra@example.net         0             1.0
# 1321184      kerrycastro@example.com      True            20.0
# 1321185       jonesmisty@example.net      True            20.0
# 1321186           erin58@example.net         0             0.0
# 1321187                            0         0             0.0
#
#          FOLLOWING_COUNT  DATASET_COUNT  CODE_COUNT  DISCUSSION_COUNT  \
# 0                   87.0            5.0         3.0             124.0
# 1                   67.0            5.0         0.0              26.0
# 2                   81.0            4.0        17.0             125.0
# 3                  114.0            5.0        24.0              67.0
# 4                  112.0            2.0        12.0              63.0
# ...                  ...            ...         ...               ...
# 1321183              3.0            0.0         1.0               9.0
# 1321184             60.0            6.0        14.0              44.0
# 1321185             64.0            3.0        24.0              67.0
# 1321186              1.0            0.0         0.0               3.0
# 1321187              3.0            0.0         0.0               0.0
#
#          AVG_NB_READ_TIME_MIN REGISTRATION_IPV4  \
# 0                        0.00      81.88.75.170
# 1                       24.97                 0
# 2                        7.75   159.202.103.178
# 3                       13.40     196.11.132.51
# 4                       24.83    159.196.199.20
# ...                       ...               ...
# 1321183                  0.26    46.209.124.151
# 1321184                 23.39   220.247.154.162
# 1321185                  9.49    150.144.209.44
# 1321186                  1.70    146.121.179.46
# 1321187                  0.53     118.38.253.89
#
#                         REGISTRATION_LOCATION  TOTAL_VOTES_GAVE_NB  \
# 0                                   Argentina                 16.0
# 1                                 New Zealand                 14.0
# 2                                  Costa Rica                 16.0
# 3                                       Italy                 21.0
# 4                                     Belgium                 10.0
# ...                                       ...                  ...
# 1321183  United States Minor Outlying Islands                 25.0
# 1321184                               Algeria                 22.0
# 1321185                               Croatia                 24.0
# 1321186                                     0                 14.0
# 1321187                          Cook Islands                 24.0
#
#          TOTAL_VOTES_GAVE_DS  TOTAL_VOTES_GAVE_DC ISBOT
# 0                       10.0                  3.0     0
# 1                        5.0                  2.0     0
# 2                        4.0                  0.0     0
# 3                       10.0                  1.0     0
# 4                        6.0                  2.0     0
# ...                      ...                  ...   ...
# 1321183                 10.0                  0.0  True
# 1321184                 10.0                  3.0     0
# 1321185                  7.0                  0.0     0
# 1321186                  8.0                  0.0  True
# 1321187                  9.0                  0.0  True
#
# [1321188 rows x 17 columns]

# %%
df.fillna(method='ffill').fillna('xx')
# Out:
#          Acc_Num                       NAME    GENDER  \
# 0        Emp_Cell         Johnny KerrThomas      Male
# 1               1         Dwayne LarsenLara      Male
# 2               2                  Emp_Cell      Male
# 3               3   Russell SimmonsPhillips      Male
# 4               4      Jamie WilsonMartinez    Female
# ...           ...                       ...       ...
# 1321183   1321183       Kristen MooreJoseph    Female
# 1321184   1321184  Kimberly ThomasGutierrez    Female
# 1321185   1321185         Hector TerryLogan      Male
# 1321186   1321186   William CollinsMartinez  Emp_Cell
# 1321187   1321187     Susan WilliamsJimenez    Female
#
#                             EMAIL_ID IS_GLOGIN FOLLOWER_COUNT FOLLOWING_COUNT  \
# 0            jacksonalan@example.com  Emp_Cell           53.0            87.0
# 1               calvin80@example.com      True           16.0            67.0
# 2                 qbrown@example.net      True           44.0            81.0
# 3         kimberlywagner@example.com      True           23.0           114.0
# 4            shaunbrooks@example.com  Emp_Cell           46.0           112.0
# ...                              ...       ...            ...             ...
# 1321183  penningtondebra@example.net  Emp_Cell            1.0             3.0
# 1321184      kerrycastro@example.com      True           20.0            60.0
# 1321185       jonesmisty@example.net      True           20.0            64.0
# 1321186           erin58@example.net  Emp_Cell       Emp_Cell             1.0
# 1321187                     Emp_Cell  Emp_Cell       Emp_Cell             3.0
#
#         DATASET_COUNT CODE_COUNT DISCUSSION_COUNT AVG_NB_READ_TIME_MIN  \
# 0                 5.0        3.0            124.0             Emp_Cell
# 1                 5.0   Emp_Cell             26.0                24.97
# 2                 4.0       17.0            125.0                 7.75
# 3                 5.0       24.0             67.0                 13.4
# 4                 2.0       12.0             63.0                24.83
# ...               ...        ...              ...                  ...
# 1321183      Emp_Cell        1.0              9.0                 0.26
# 1321184           6.0       14.0             44.0                23.39
# 1321185           3.0       24.0             67.0                 9.49
# 1321186      Emp_Cell   Emp_Cell              3.0                  1.7
# 1321187      Emp_Cell   Emp_Cell         Emp_Cell                 0.53
#
#         REGISTRATION_IPV4                 REGISTRATION_LOCATION  \
# 0            81.88.75.170                             Argentina
# 1                Emp_Cell                           New Zealand
# 2         159.202.103.178                            Costa Rica
# 3           196.11.132.51                                 Italy
# 4          159.196.199.20                               Belgium
# ...                   ...                                   ...
# 1321183    46.209.124.151  United States Minor Outlying Islands
# 1321184   220.247.154.162                               Algeria
# 1321185    150.144.209.44                               Croatia
# 1321186    146.121.179.46                              Emp_Cell
# 1321187     118.38.253.89                          Cook Islands
#
#         TOTAL_VOTES_GAVE_NB TOTAL_VOTES_GAVE_DS TOTAL_VOTES_GAVE_DC     ISBOT
# 0                      16.0                10.0                 3.0  Emp_Cell
# 1                      14.0                 5.0                 2.0  Emp_Cell
# 2                      16.0                 4.0            Emp_Cell  Emp_Cell
# 3                      21.0                10.0                 1.0  Emp_Cell
# 4                      10.0                 6.0                 2.0  Emp_Cell
# ...                     ...                 ...                 ...       ...
# 1321183                25.0                10.0            Emp_Cell      True
# 1321184                22.0                10.0                 3.0  Emp_Cell
# 1321185                24.0                 7.0            Emp_Cell  Emp_Cell
# 1321186                14.0                 8.0            Emp_Cell      True
# 1321187                24.0                 9.0            Emp_Cell      True
#
# [1321188 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# Acc_Num                  0
# NAME                     0
# GENDER                   0
# EMAIL_ID                 0
# IS_GLOGIN                0
# FOLLOWER_COUNT           0
# FOLLOWING_COUNT          0
# DATASET_COUNT            0
# CODE_COUNT               0
# DISCUSSION_COUNT         0
# AVG_NB_READ_TIME_MIN     0
# REGISTRATION_IPV4        0
# REGISTRATION_LOCATION    0
# TOTAL_VOTES_GAVE_NB      0
# TOTAL_VOTES_GAVE_DS      0
# TOTAL_VOTES_GAVE_DC      0
# ISBOT                    0
# dtype: int64

# %%
df.dropna(subset=['EMAIL_ID'],inplace = True)
df
# Out:
#          Acc_Num                       NAME    GENDER  \
# 0        Emp_Cell         Johnny KerrThomas      Male
# 1               1         Dwayne LarsenLara      Male
# 2               2                  Emp_Cell      Male
# 3               3   Russell SimmonsPhillips      Male
# 4               4      Jamie WilsonMartinez    Female
# ...           ...                       ...       ...
# 1321183   1321183       Kristen MooreJoseph    Female
# 1321184   1321184  Kimberly ThomasGutierrez    Female
# 1321185   1321185         Hector TerryLogan      Male
# 1321186   1321186   William CollinsMartinez  Emp_Cell
# 1321187   1321187     Susan WilliamsJimenez    Female
#
#                             EMAIL_ID IS_GLOGIN FOLLOWER_COUNT FOLLOWING_COUNT  \
# 0            jacksonalan@example.com  Emp_Cell           53.0            87.0
# 1               calvin80@example.com      True           16.0            67.0
# 2                 qbrown@example.net      True           44.0            81.0
# 3         kimberlywagner@example.com      True           23.0           114.0
# 4            shaunbrooks@example.com  Emp_Cell           46.0           112.0
# ...                              ...       ...            ...             ...
# 1321183  penningtondebra@example.net  Emp_Cell            1.0             3.0
# 1321184      kerrycastro@example.com      True           20.0            60.0
# 1321185       jonesmisty@example.net      True           20.0            64.0
# 1321186           erin58@example.net  Emp_Cell       Emp_Cell             1.0
# 1321187                     Emp_Cell  Emp_Cell       Emp_Cell             3.0
#
#         DATASET_COUNT CODE_COUNT DISCUSSION_COUNT AVG_NB_READ_TIME_MIN  \
# 0                 5.0        3.0            124.0             Emp_Cell
# 1                 5.0   Emp_Cell             26.0                24.97
# 2                 4.0       17.0            125.0                 7.75
# 3                 5.0       24.0             67.0                 13.4
# 4                 2.0       12.0             63.0                24.83
# ...               ...        ...              ...                  ...
# 1321183      Emp_Cell        1.0              9.0                 0.26
# 1321184           6.0       14.0             44.0                23.39
# 1321185           3.0       24.0             67.0                 9.49
# 1321186      Emp_Cell   Emp_Cell              3.0                  1.7
# 1321187      Emp_Cell   Emp_Cell         Emp_Cell                 0.53
#
#         REGISTRATION_IPV4                 REGISTRATION_LOCATION  \
# 0            81.88.75.170                             Argentina
# 1                Emp_Cell                           New Zealand
# 2         159.202.103.178                            Costa Rica
# 3           196.11.132.51                                 Italy
# 4          159.196.199.20                               Belgium
# ...                   ...                                   ...
# 1321183    46.209.124.151  United States Minor Outlying Islands
# 1321184   220.247.154.162                               Algeria
# 1321185    150.144.209.44                               Croatia
# 1321186    146.121.179.46                              Emp_Cell
# 1321187     118.38.253.89                          Cook Islands
#
#         TOTAL_VOTES_GAVE_NB TOTAL_VOTES_GAVE_DS TOTAL_VOTES_GAVE_DC     ISBOT
# 0                      16.0                10.0                 3.0  Emp_Cell
# 1                      14.0                 5.0                 2.0  Emp_Cell
# 2                      16.0                 4.0            Emp_Cell  Emp_Cell
# 3                      21.0                10.0                 1.0  Emp_Cell
# 4                      10.0                 6.0                 2.0  Emp_Cell
# ...                     ...                 ...                 ...       ...
# 1321183                25.0                10.0            Emp_Cell      True
# 1321184                22.0                10.0                 3.0  Emp_Cell
# 1321185                24.0                 7.0            Emp_Cell  Emp_Cell
# 1321186                14.0                 8.0            Emp_Cell      True
# 1321187                24.0                 9.0            Emp_Cell      True
#
# [1321188 rows x 17 columns]

# %%
print('the num of null mails as will be unknown cuts is ->',1321188-1243374)
# Out:
# the num of null mails as will be unknown cuts is -> 77814

# %%
print('the perecentage of missing is ' , (77814/1321188)*100 )
# Out:
# the perecentage of missing is  5.8896992706564095

# %%
df.drop_duplicates(inplace = True)

# %%
df=df.replace("", np.nan)

# %%
df.dtypes
# Out:
# Acc_Num                  object
# NAME                     object
# GENDER                   object
# EMAIL_ID                 object
# IS_GLOGIN                object
# FOLLOWER_COUNT           object
# FOLLOWING_COUNT          object
# DATASET_COUNT            object
# CODE_COUNT               object
# DISCUSSION_COUNT         object
# AVG_NB_READ_TIME_MIN     object
# REGISTRATION_IPV4        object
# REGISTRATION_LOCATION    object
# TOTAL_VOTES_GAVE_NB      object
# TOTAL_VOTES_GAVE_DS      object
# TOTAL_VOTES_GAVE_DC      object
# ISBOT                    object
# dtype: object

# %%
pd.isna(df['NAME']).value_counts()
# Out:
# False    1321188
# Name: NAME, dtype: int64

# %% [markdown]
# ### Data Processing

# %%
df.describe()
# Out:
#         Acc_Num       NAME   GENDER  EMAIL_ID IS_GLOGIN FOLLOWER_COUNT  \
# count    1321188   1321188  1321188   1321188   1321188        1321188
# unique   1321188   1199434        3    603014         2             71
# top     Emp_Cell  Emp_Cell     Male  Emp_Cell  Emp_Cell       Emp_Cell
# freq           1     78164   932220     77814    866275         188410
#
#        FOLLOWING_COUNT DATASET_COUNT CODE_COUNT DISCUSSION_COUNT  \
# count          1321188       1321188    1321188          1321188
# unique             121             8         25              140
# top           Emp_Cell      Emp_Cell   Emp_Cell         Emp_Cell
# freq            161538        524974     244148           101378
#
#        AVG_NB_READ_TIME_MIN REGISTRATION_IPV4 REGISTRATION_LOCATION  \
# count               1321188           1321188               1321188
# unique                 2548           1242580                   244
# top                Emp_Cell          Emp_Cell              Emp_Cell
# freq                  79956             78329                 78290
#
#         TOTAL_VOTES_GAVE_NB  TOTAL_VOTES_GAVE_DS TOTAL_VOTES_GAVE_DC     ISBOT
# count             1321188.0            1321188.0             1321188   1321188
# unique                 17.0                  9.0                   4         2
# top                    24.0                  9.0            Emp_Cell  Emp_Cell
# freq                78215.0             155759.0              388793    988294

# %%
# df['FOLLOWER_COUNT']=df['FOLLOWER_COUNT'].astype(float)
# df['FOLLOWER_COUNT'].agg('mean')

# %%
ex1=df.groupby(['NAME'])[[
    'FOLLOWER_COUNT',
    'FOLLOWING_COUNT',
    'REGISTRATION_LOCATION']].mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20152\2060841973.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   ex1=df.groupby(['NAME'])[[

# %%
ex1.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Aaron AbbottMontgomery, Aaron AbbottRobinson, Aaron AbbottSchwartz, Aaron AcevedoSwanson, Aaron AcostaCarpenter, Aaron AcostaCraig, Aaron AcostaDean, Aaron AdamsBailey, Aaron AdamsBruce, Aaron AdamsCannon]

# %%
# the percentage of true \ false \ no ans at all .. due to 'isBot'
df['ISBOT'].value_counts()
# Out:
# Emp_Cell    988294
# True        332894
# Name: ISBOT, dtype: int64

# %%
# total answers 
df['ISBOT'].value_counts().sum()
# Out:
# 1321188

# %%
# if ture 
if_true = (313217 / 1243374)*100
if_false = (856254 / 1243374)*100
if_no_ans = (73903 / 1243374) * 100 
print(if_true,"\\",if_false,"\\",if_no_ans)
# Out:
# 25.190891879675785 \ 68.8653615082831 \ 5.9437466120411075

# %%
df
# Out:
#          Acc_Num                       NAME    GENDER  \
# 0        Emp_Cell         Johnny KerrThomas      Male
# 1               1         Dwayne LarsenLara      Male
# 2               2                  Emp_Cell      Male
# 3               3   Russell SimmonsPhillips      Male
# 4               4      Jamie WilsonMartinez    Female
# ...           ...                       ...       ...
# 1321183   1321183       Kristen MooreJoseph    Female
# 1321184   1321184  Kimberly ThomasGutierrez    Female
# 1321185   1321185         Hector TerryLogan      Male
# 1321186   1321186   William CollinsMartinez  Emp_Cell
# 1321187   1321187     Susan WilliamsJimenez    Female
#
#                             EMAIL_ID IS_GLOGIN FOLLOWER_COUNT FOLLOWING_COUNT  \
# 0            jacksonalan@example.com  Emp_Cell           53.0            87.0
# 1               calvin80@example.com      True           16.0            67.0
# 2                 qbrown@example.net      True           44.0            81.0
# 3         kimberlywagner@example.com      True           23.0           114.0
# 4            shaunbrooks@example.com  Emp_Cell           46.0           112.0
# ...                              ...       ...            ...             ...
# 1321183  penningtondebra@example.net  Emp_Cell            1.0             3.0
# 1321184      kerrycastro@example.com      True           20.0            60.0
# 1321185       jonesmisty@example.net      True           20.0            64.0
# 1321186           erin58@example.net  Emp_Cell       Emp_Cell             1.0
# 1321187                     Emp_Cell  Emp_Cell       Emp_Cell             3.0
#
#         DATASET_COUNT CODE_COUNT DISCUSSION_COUNT AVG_NB_READ_TIME_MIN  \
# 0                 5.0        3.0            124.0             Emp_Cell
# 1                 5.0   Emp_Cell             26.0                24.97
# 2                 4.0       17.0            125.0                 7.75
# 3                 5.0       24.0             67.0                 13.4
# 4                 2.0       12.0             63.0                24.83
# ...               ...        ...              ...                  ...
# 1321183      Emp_Cell        1.0              9.0                 0.26
# 1321184           6.0       14.0             44.0                23.39
# 1321185           3.0       24.0             67.0                 9.49
# 1321186      Emp_Cell   Emp_Cell              3.0                  1.7
# 1321187      Emp_Cell   Emp_Cell         Emp_Cell                 0.53
#
#         REGISTRATION_IPV4                 REGISTRATION_LOCATION  \
# 0            81.88.75.170                             Argentina
# 1                Emp_Cell                           New Zealand
# 2         159.202.103.178                            Costa Rica
# 3           196.11.132.51                                 Italy
# 4          159.196.199.20                               Belgium
# ...                   ...                                   ...
# 1321183    46.209.124.151  United States Minor Outlying Islands
# 1321184   220.247.154.162                               Algeria
# 1321185    150.144.209.44                               Croatia
# 1321186    146.121.179.46                              Emp_Cell
# 1321187     118.38.253.89                          Cook Islands
#
#         TOTAL_VOTES_GAVE_NB TOTAL_VOTES_GAVE_DS TOTAL_VOTES_GAVE_DC     ISBOT
# 0                      16.0                10.0                 3.0  Emp_Cell
# 1                      14.0                 5.0                 2.0  Emp_Cell
# 2                      16.0                 4.0            Emp_Cell  Emp_Cell
# 3                      21.0                10.0                 1.0  Emp_Cell
# 4                      10.0                 6.0                 2.0  Emp_Cell
# ...                     ...                 ...                 ...       ...
# 1321183                25.0                10.0            Emp_Cell      True
# 1321184                22.0                10.0                 3.0  Emp_Cell
# 1321185                24.0                 7.0            Emp_Cell  Emp_Cell
# 1321186                14.0                 8.0            Emp_Cell      True
# 1321187                24.0                 9.0            Emp_Cell      True
#
# [1321188 rows x 17 columns]

# %%
type('FOLLOWER_COUNT')
df['FOLLOWER_COUNT']=df['FOLLOWER_COUNT'].astype(float)

# %% [markdown]
# ### Data Visulisation

# %%
high = df['FOLLOWER_COUNT'].mean()
highest = df[df['FOLLOWER_COUNT']>high]
highest

#most_follwed_accounts
# Out:
#          Acc_Num                       NAME  GENDER  \
# 0               0         Johnny KerrThomas    Male
# 2               2                         0    Male
# 4               4      Jamie WilsonMartinez  Female
# 6               6  Logan ZimmermanGallagher    Male
# 8               8      Matthew RobertsGreer    Male
# ...           ...                       ...     ...
# 1321168   1321168     Kayla HernandezChavez  Female
# 1321173   1321173       Jennifer MooreJones  Female
# 1321175   1321175     Shelley GallegosBurke  Female
# 1321178   1321178    Micheal CrawfordTaylor    Male
# 1321182   1321182          Sean LopezWilson    Male
#
#                             EMAIL_ID IS_GLOGIN  FOLLOWER_COUNT  \
# 0            jacksonalan@example.com         0            53.0
# 2                 qbrown@example.net      True            44.0
# 4            shaunbrooks@example.com         0            46.0
# 6          sparkschristy@example.org         0            46.0
# 8           harrisregina@example.org      True            50.0
# ...                              ...       ...             ...
# 1321168         xsimmons@example.com      True            57.0
# 1321173  richardsonkevin@example.com         0            42.0
# 1321175        moramegan@example.net         0            66.0
# 1321178          ebryant@example.org         0            37.0
# 1321182          fmartin@example.org      True            46.0
#
#          FOLLOWING_COUNT  DATASET_COUNT  CODE_COUNT  DISCUSSION_COUNT  \
# 0                   87.0            5.0         3.0             124.0
# 2                   81.0            4.0        17.0             125.0
# 4                  112.0            2.0        12.0              63.0
# 6                   36.0            0.0        16.0              77.0
# 8                   25.0            1.0         7.0             122.0
# ...                  ...            ...         ...               ...
# 1321168             44.0            7.0        19.0              34.0
# 1321173             31.0            5.0        12.0              60.0
# 1321175             27.0            0.0        13.0             127.0
# 1321178             63.0            3.0        18.0              61.0
# 1321182              7.0            7.0        21.0               0.0
#
#          AVG_NB_READ_TIME_MIN REGISTRATION_IPV4  \
# 0                        0.00      81.88.75.170
# 2                        7.75   159.202.103.178
# 4                       24.83    159.196.199.20
# 6                       22.32    133.206.76.136
# 8                        0.00    192.177.30.226
# ...                       ...               ...
# 1321168                 26.20     198.28.175.37
# 1321173                 26.36     43.68.146.166
# 1321175                 21.78    128.17.171.202
# 1321178                 27.29    155.16.177.248
# 1321182                 21.65    221.99.255.210
#
#                                 REGISTRATION_LOCATION  TOTAL_VOTES_GAVE_NB  \
# 0                                           Argentina                 16.0
# 2                                          Costa Rica                 16.0
# 4                                             Belgium                 10.0
# 6        South Georgia and the South Sandwich Islands                  0.0
# 8                                                   0                  0.0
# ...                                               ...                  ...
# 1321168                                          Iraq                 25.0
# 1321173                                   Switzerland                 20.0
# 1321175                                  Cook Islands                 17.0
# 1321178                                       Albania                 25.0
# 1321182                                        Mexico                 23.0
#
#          TOTAL_VOTES_GAVE_DS  TOTAL_VOTES_GAVE_DC ISBOT
# 0                       10.0                  3.0     0
# 2                        4.0                  0.0     0
# 4                        6.0                  2.0     0
# 6                        9.0                  1.0     0
# 8                        7.0                  3.0     0
# ...                      ...                  ...   ...
# 1321168                  5.0                  0.0     0
# 1321173                  7.0                  2.0     0
# 1321175                  4.0                  3.0     0
# 1321178                  9.0                  3.0     0
# 1321182                  5.0                  0.0     0
#
# [602618 rows x 17 columns]

# %%
highest.describe()
# Out:
#            Acc_Num   FOLLOWER_COUNT  FOLLOWING_COUNT  DATASET_COUNT  \
# count  6.026180e+05   602618.000000    602618.000000  602618.000000
# mean   6.609195e+05       47.983605        57.384366       3.289656
# std    3.812090e+05       12.989922        36.326132       2.373019
# min    0.000000e+00       26.000000         0.000000       0.000000
# 25%    3.309950e+05       37.000000        26.000000       1.000000
# 50%    6.617465e+05       48.000000        57.000000       3.000000
# 75%    9.907390e+05       59.000000        89.000000       5.000000
# max    1.321182e+06       70.000000       120.000000       7.000000
#
#           CODE_COUNT  DISCUSSION_COUNT  AVG_NB_READ_TIME_MIN  \
# count  602618.000000     602618.000000          602618.00000
# mean       13.181148         82.411709              16.01665
# std         7.232581         40.847845               8.31451
# min         0.000000          0.000000               0.00000
# 25%         7.000000         50.000000               9.31000
# 50%        13.000000         84.000000              16.21000
# 75%        19.000000        117.000000              23.16000
# max        25.000000        150.000000              29.99000
#
#        TOTAL_VOTES_GAVE_NB  TOTAL_VOTES_GAVE_DS  TOTAL_VOTES_GAVE_DC
# count        602618.000000        602618.000000        602618.000000
# mean             16.470696             6.113925             1.413856
# std               6.080906             2.699059             1.141081
# min               0.000000             0.000000             0.000000
# 25%              13.000000             4.000000             0.000000
# 50%              17.000000             6.000000             1.000000
# 75%              21.000000             8.000000             2.000000
# max              25.000000            10.000000             3.000000

# %%
# The Highest 50 Country 
h=df['REGISTRATION_LOCATION'].value_counts().head(50)
h
# Out:
# 0                                               78290
# Korea                                           10128
# Congo                                           10045
# Costa Rica                                       5304
# Canada                                           5261
# Armenia                                          5241
# Cocos (Keeling) Islands                          5241
# Finland                                          5239
# Montserrat                                       5235
# Italy                                            5229
# Cameroon                                         5224
# Afghanistan                                      5221
# France                                           5220
# Zambia                                           5209
# Belize                                           5206
# China                                            5204
# Lao People's Democratic Republic                 5199
# Kiribati                                         5196
# Swaziland                                        5192
# Poland                                           5190
# Suriname                                         5187
# Gabon                                            5184
# Mongolia                                         5181
# Portugal                                         5179
# Solomon Islands                                  5175
# Cyprus                                           5174
# Japan                                            5170
# Ukraine                                          5168
# Malawi                                           5166
# Falkland Islands (Malvinas)                      5165
# Uganda                                           5164
# Sweden                                           5164
# Peru                                             5164
# Palestinian Territory                            5163
# Colombia                                         5162
# Cook Islands                                     5161
# Israel                                           5161
# Norfolk Island                                   5161
# Kyrgyz Republic                                  5161
# Jersey                                           5160
# Netherlands Antilles                             5159
# Argentina                                        5159
# Liechtenstein                                    5157
# Honduras                                         5157
# Romania                                          5155
# Tunisia                                          5154
# Lesotho                                          5154
# Saint Barthelemy                                 5153
# Antarctica (the territory South of 60 deg S)     5153
# Somalia                                          5148
# Name: REGISTRATION_LOCATION, dtype: int64

# %%
h.plot()


plt.show()

# %%
df['IS_GLOGIN'].value_counts()
# Out:
# 0       866275
# True    454913
# Name: IS_GLOGIN, dtype: int64

# %%
# graph to ddetect the side of differient value if (IS_BOT) filed 

# df['IS_GLOGIN'].value_counts()
# c=df['IS_GLOGIN'].value_counts()
# plt.pie([c[1]] )




import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
x =df['IS_GLOGIN'].value_counts()[0]
y = df['IS_GLOGIN'].value_counts()[1]

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 8), xticks=np.arange(100000, 800000),
       ylim=(0, 8), yticks=np.arange(100000, 500000))

plt.show()

# %%
# depending on each Country the results will be 
# with the same fields of bot & male & if it logging or not 


con_gender_bot = df.groupby('REGISTRATION_LOCATION')['IS_GLOGIN','GENDER','ISBOT'].value_counts().head(50)
con_gender_bot
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20152\2344802274.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   con_gender_bot = df.groupby('REGISTRATION_LOCATION')['IS_GLOGIN','GENDER','ISBOT'].value_counts().head(50)
# REGISTRATION_LOCATION  IS_GLOGIN  GENDER  ISBOT
# 0                      0          Male    0        22295
#                        True       Male    0        19096
#                        0          Male    True     13945
#                                   Female  0         7522
#                        True       Female  0         6297
#                        0          Female  True      4614
#                                   0       0         1756
#                        True       0       0         1596
#                        0          0       True      1169
# Afghanistan            0          Male    0         1480
#                        True       Male    0         1246
#                        0          Male    True       941
#                                   Female  0          513
#                        True       Female  0          405
#                        0          Female  True       300
#                                   0       0          135
#                        True       0       0          110
#                        0          0       True        91
# Albania                0          Male    0         1356
#                        True       Male    0         1216
#                        0          Male    True       904
#                                   Female  0          479
#                        True       Female  0          446
#                        0          Female  True       285
#                        True       0       0          102
#                        0          0       0           96
#                                           True        78
# Algeria                0          Male    0         1390
#                        True       Male    0         1224
#                        0          Male    True       896
#                                   Female  0          503
#                        True       Female  0          421
#                        0          Female  True       308
#                                   0       0          127
#                        True       0       0           98
#                        0          0       True        72
# American Samoa         0          Male    0         1415
#                        True       Male    0         1251
#                        0          Male    True       883
#                                   Female  0          505
#                        True       Female  0          426
#                        0          Female  True       301
#                        True       0       0          113
#                        0          0       0          111
#                                           True        88
# Andorra                0          Male    0         1441
#                        True       Male    0         1262
#                        0          Male    True       884
#                                   Female  0          463
#                        True       Female  0          418
# dtype: int64

# %%
# TOTAL_VOTES_GAVE_NB: The total number of votes the individual has given to notebooks.
# and if it male or fe male && bot or not 
# calc all cases and with recpect to all fields with all values 

vots_gender_bot= df.groupby('TOTAL_VOTES_GAVE_NB')['IS_GLOGIN','GENDER','ISBOT'].value_counts().head(50)
vots_gender_bot
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20152\3271797593.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   vots_gender_bot= df.groupby('TOTAL_VOTES_GAVE_NB')['IS_GLOGIN','GENDER','ISBOT'].value_counts().head(50)
# TOTAL_VOTES_GAVE_NB  IS_GLOGIN  GENDER  ISBOT
# 0.0                  0          Male    0        22228
#                      True       Male    0        18734
#                      0          Male    True     13843
#                                 Female  0         7357
#                      True       Female  0         6204
#                      0          Female  True      4691
#                                 0       0         1848
#                      True       0       0         1617
#                      0          0       True      1183
# 10.0                 0          Male    0        22205
#                      True       Male    0        18677
#                      0          Male    True     13704
#                                 Female  0         7469
#                      True       Female  0         6369
#                      0          Female  True      4648
#                                 0       0         1798
#                      True       0       0         1556
#                      0          0       True      1215
# 11.0                 0          Male    0        21983
#                      True       Male    0        19051
#                      0          Male    True     13721
#                                 Female  0         7619
#                      True       Female  0         6298
#                      0          Female  True      4471
#                                 0       0         1830
#                      True       0       0         1614
#                      0          0       True      1077
# 12.0                 0          Male    0        22035
#                      True       Male    0        18833
#                      0          Male    True     13844
#                                 Female  0         7341
#                      True       Female  0         6326
#                      0          Female  True      4415
#                                 0       0         1827
#                      True       0       0         1609
#                      0          0       True      1161
# 13.0                 0          Male    0        22304
#                      True       Male    0        18942
#                      0          Male    True     13764
#                                 Female  0         7401
#                      True       Female  0         6467
#                      0          Female  True      4664
#                                 0       0         1787
#                      True       0       0         1621
#                      0          0       True      1113
# 14.0                 0          Male    0        22191
#                      True       Male    0        18920
#                      0          Male    True     13747
#                                 Female  0         7280
#                      True       Female  0         6235
# dtype: int64

# %%
# try to count all cases and maybe collecti
df.groupby('REGISTRATION_LOCATION')['IS_GLOGIN','GENDER','ISBOT'].value_counts()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20152\2736614608.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('REGISTRATION_LOCATION')['IS_GLOGIN','GENDER','ISBOT'].value_counts()
# REGISTRATION_LOCATION  IS_GLOGIN  GENDER  ISBOT
# 0                      0          Male    0        22295
#                        True       Male    0        19096
#                        0          Male    True     13945
#                                   Female  0         7522
#                        True       Female  0         6297
#                                                    ...
# Zimbabwe               True       Female  0          416
#                        0          Female  True       290
#                                   0       0          143
#                        True       0       0          102
#                        0          0       True        71
# Length: 2196, dtype: int64

# %%
# AVG_NB_READ_TIME_MIN: The average time spent reading notebooks in minutes.
# the num of data sets that user has created before && depending on this u can judge which one is fake or not 
# and coverd with the option the if it bot or not that will help to decide if it fake or not 

df.groupby('NAME')['DATASET_COUNT','ISBOT','AVG_NB_READ_TIME_MIN'].value_counts()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20152\1436414795.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('NAME')['DATASET_COUNT','ISBOT','AVG_NB_READ_TIME_MIN'].value_counts()
# NAME                DATASET_COUNT  ISBOT  AVG_NB_READ_TIME_MIN
# 0                   0.0            True   0.00                    1246
#                                    0      0.00                     672
#                     7.0            0      0.00                     406
#                     1.0            0      0.00                     404
#                     5.0            0      0.00                     401
#                                                                   ...
# Zoe WilliamsMiller  3.0            0      18.70                      1
# Zoe WillisGreen     2.0            0      26.65                      1
# Zoe WilsonGreen     5.0            0      29.95                      1
# Zoe WoodHines       4.0            0      28.99                      1
# Zoe YoderSmith      0.0            0      1.93                       1
# Length: 1260880, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Acc_Num ',
#  'NAME',
#  'GENDER',
#  'EMAIL_ID',
#  'IS_GLOGIN',
#  'FOLLOWER_COUNT',
#  'FOLLOWING_COUNT',
#  'DATASET_COUNT',
#  'CODE_COUNT',
#  'DISCUSSION_COUNT',
#  'AVG_NB_READ_TIME_MIN',
#  'REGISTRATION_IPV4',
#  'REGISTRATION_LOCATION',
#  'TOTAL_VOTES_GAVE_NB',
#  'TOTAL_VOTES_GAVE_DS',
#  'TOTAL_VOTES_GAVE_DC',
#  'ISBOT']

# %%
import matplotlib.pyplot as plt
plt.scatter(con_gender_bot, vots_gender_bot,color='b' , linewidth = 1 , marker = '*' ,linestyle = 'dashed')
  
plt.xlabel('con_gender_bot - axis')
plt.ylabel('vots_gender_bot - axis')



plt.legend()

plt.title('the separation ')
  
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df=pd.read_csv('D:\data sets\kaggle_bot_accounts.csv')
plt.title("the relationship bettween vots_gender_bot & con_gender_bot ")
plt.plot(vots_gender_bot,con_gender_bot,'r.-'  )
plt.xticks(vots_gender_bot)
plt.yticks(con_gender_bot)
print(vots_gender_bot[::7])
print(con_gender_bot[::7])
# plt.show()
# Out:
# TOTAL_VOTES_GAVE_NB  IS_GLOGIN  GENDER  ISBOT
# 0.0                  0          Male    0        22228
#                      True       0       0         1617
# 10.0                 0          Female  True      4648
# 11.0                 0          Female  0         7619
# 12.0                 True       Male    0        18833
#                      0          0       True      1161
# 13.0                 0          0       0         1787
# 14.0                 True       Female  0         6235
# dtype: int64
# REGISTRATION_LOCATION  IS_GLOGIN  GENDER  ISBOT
# 0                      0          Male    0        22295
#                        True       0       0         1596
# Afghanistan            0          Female  True       300
# Albania                0          Female  0          479
# Algeria                True       Male    0         1224
#                        0          0       True        72
# American Samoa         True       0       0          113
# Andorra                True       Female  0          418
# dtype: int64

# %%
for REGISTRATION_LOCATION in df :
    if REGISTRATION_LOCATION in ['Korea' , 'Afghanistan','Algeria']:
        plt.plot(df['TOTAL_VOTES_GAVE_NB'] , marker = '.')

# %%
df['CODE_COUNT']=df['CODE_COUNT'].astype(float)
df['DATASET_COUNT']=df['DATASET_COUNT'].astype(float)

# %%
plt.hist(df.CODE_COUNT , color = 'black' )
plt.xlabel('Num Of NoteBooks')
plt.ylabel('Num Of persons')
plt.title("The number of notebooks the individual has created")
plt.show()

# %%
Argentina = df.loc[df['REGISTRATION_LOCATION'] == 'Argentina'].count()[0]
Korea = df.loc[df['REGISTRATION_LOCATION'] == 'Korea'].count()[0]
Costa_Rica = df.loc[df['REGISTRATION_LOCATION'] == 'Costa Rica'].count()[0]
Italy= df.loc[df['REGISTRATION_LOCATION'] == 'Italy'].count()[5]
labels = ['Argentina','Korea','Costa_Rica','Italy']
colors = ['b','r','g','y']
plt.pie([Argentina,Korea,Costa_Rica,Italy],labels=labels, colors=colors )

plt.title("a random sample from she contries to clear what i`m doing")

plt.show()

# %%
# df['DATASET_COUNT']=df['DATASET_COUNT'].astype(float)
# df['TOTAL_VOTES_GAVE_DC']=df['TOTAL_VOTES_GAVE_DC'].astype(float)

# %%
# x=df['REGISTRATION_LOCATION']
# y=df['TOTAL_VOTES_GAVE_NB']
# plt.plot(x,y,label='2x' , color='b' , linewidth = 3  , marker = '.' , markersize = 13 , markeredgecolor = 'r' , linestyle = 'dashed')


x=['REGISTRATION_LOCATION']
y=['TOTAL_VOTES_GAVE_DC']

plt.plot(x,y,label='4x' , color='b' , linewidth = 10 , marker = '.' , markersize = 16 )

plt.title("the relationship! ",fontdict = {'fontname':'Comic Sans MS' , 'fontsize' : 20})


plt.show()

# %%
# df.plot(x='FOLLOWER_COUNT', y='FOLLOWING_COUNT',kind='bar');

# %%
# df.plot(subplots=True, figsize=(8, 8))

# %%
# df.plot(kind="bar")
# #
